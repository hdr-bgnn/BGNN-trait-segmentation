# %% [raw]
# '''
# This notebook contains the general training module to train the segmentation model.
# The supervision is guided by the ground-truth segmentation labels and the prediction consistency
# of RN. At first, we will only use dorsal-to RN to evaluate the prediction performance.
# '''

# %%
# %matplotlib inline
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image

from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

import torch
import segmentation_models_pytorch as smp
import albumentations as albu

import seaborn as sns
import pylab as py
import pandas as pd

from scripts.preprocessing import Dataset
from scripts.helper import plot_double_image, plot_triple_image, get_color_img, get_concat_h
from scripts.augmentation import get_training_augmentation, get_validation_augmentation, to_tensor, get_preprocessing, get_preprocessing_unlabeled

DEVICE = ('cuda:4' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# #### Directories

# %%
##### Assign the location of your datasets

DATA_DIR = '/raid/maruf/data-800/'
# train set
x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'trainannot')
# validation set
x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'valannot')
# test set
x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'testannot')

# %% [markdown]
# #### Pretrained Model

# %%
# encoder: resnext50
# encoder weights: imagenet
# segmentation model: FPN 

ENCODER = 'se_resnext50_32x4d'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = ['dorsal', 'adipose', 'caudal', 'anal', 
           'pelvic', 'pectoral', 'head', 'eye', 
           'caudal-ray', 'alt-ray', 'alt-spine', 'trunk']
ACTIVATION = 'sigmoid'
# segmentation model with pretrained encoder
model = smp.FPN(
    encoder_name = ENCODER,
    encoder_weights = ENCODER_WEIGHTS,
    classes = len(CLASSES),
    activation = ACTIVATION,
)
# preprocessing function for this encoder
preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %% [markdown]
# #### Dataset and Dataloader

# %%
train_dataset = Dataset(
    x_train_dir,
    y_train_dir,
    augmentation = get_training_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    classes = CLASSES,
)

valid_dataset = Dataset(
    x_valid_dir,
    y_valid_dir,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    classes = CLASSES,
)

test_dataset = Dataset(
    x_test_dir,
    y_test_dir,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    classes = CLASSES,
)

# loading data from the dataset
train_loader = DataLoader(train_dataset, batch_size = 8, shuffle=True, num_workers = 12)
valid_loader = DataLoader(valid_dataset, batch_size = 1, shuffle=False, num_workers = 4)
test_loader = DataLoader(test_dataset)

# %% [markdown]
# #### Optimizer, Loss and Metrics

# %%
# optimizers
optimizer = torch.optim.Adam([
    dict(params = model.parameters(), lr = 0.0001),
])

# loss = dice lose, metric = iou_score
loss = smp.utils.losses.DiceLoss()
metrics = [
    smp.utils.metrics.IoU(threshold=0.5)
]

# %%
# load RN model
from scripts.RN import RN
rn_model = RN().to(DEVICE)
rn_model.load_state_dict(torch.load('saved_models/rn_model.pt'))
rn_loss = torch.nn.BCELoss()

# %% [markdown]
# #### Iterators for Dataloaders

# %%
from scripts.utils.train import TrainEpoch, ValidEpoch

train_epoch = TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 0.001,
)

valid_epoch = ValidEpoch(
    model,
    loss = loss,
    metrics = metrics,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 0.001,
)

# %% [markdown]
# #### Training

# %%
# # We will train the model for 120 epochs
number_epoch = 50
max_score = 0

conv_train = {'dice': [],
              'RN': [],
              'iou': [],}
conv_valid = {'dice': [],
              'RN': [],
              'iou': [],}

for i in range(0, number_epoch):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)
    
    # to save model
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, 'saved_models/best_model_random_lambda_0pt001.pth')
        print('Model saved!')
        
    # step wise loss function
    # lr changed after 25 epochs
    
    conv_train['dice'].append(train_logs['dice_loss'])    
    conv_train['RN'].append(train_logs['RNLoss'])     
    conv_train['iou'].append(train_logs['iou_score'])
    
    conv_valid['dice'].append(valid_logs['dice_loss'])    
    conv_valid['RN'].append(valid_logs['RNLoss'])     
    conv_valid['iou'].append(valid_logs['iou_score'])
    
    
    if i == 25:
        optimizer.param_groups[0]['lr'] = 1e-5
        print('Decrease decoder learning rate to 1e-5')
        
    if i % 10 == 0:
        image, mask = test_dataset[0]
        img_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
        pred_mask = model.predict(img_tensor)
        pred_mask = pred_mask.squeeze().cpu().numpy().round()
        if os.path.exists('Segmentations/SM_RN_0pt001/epoch_'+str(i)+'/') is False:
            os.makedirs('Segmentations/SM_RN_0pt001/epoch_'+str(i)+'/')
        get_color_img(pred_mask, normal=False).save('Segmentations/SM_RN_0pt001/epoch_'+str(i)+'/prediction.png')
        # write the scores
        
        with open('Segmentations/SM_RN_0pt001/epoch_'+str(i)+'/scores.txt', 'w+') as f:
            f.write('dice_loss:'+str(train_logs['dice_loss'])+'\n')
            f.write('RNLoss:'+str(train_logs['RNLoss'])+'\n')
            f.write('iou_score:'+str(train_logs['iou_score'])+'\n')
# Out:
# Epoch: 0
# train: 100%|██████████| 37/37 [00:17<00:00,  2.16it/s, dice_loss - 0.0458, RNLoss - 0.02548, iou_score - 0.9157]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.40it/s, dice_loss - 0.05793, RNLoss - 0.0, iou_score - 0.8936]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 37/37 [00:16<00:00,  2.24it/s, dice_loss - 0.0441, RNLoss - 0.1321, iou_score - 0.9191]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.66it/s, dice_loss - 0.05804, RNLoss - 0.0, iou_score - 0.8934]
#
# Epoch: 2
# train: 100%|██████████| 37/37 [00:16<00:00,  2.21it/s, dice_loss - 0.04602, RNLoss - 0.05231, iou_score - 0.9154]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.29it/s, dice_loss - 0.0583, RNLoss - 0.0, iou_score - 0.8929]
#
# Epoch: 3
# train: 100%|██████████| 37/37 [00:16<00:00,  2.20it/s, dice_loss - 0.04393, RNLoss - 0.01299, iou_score - 0.9191]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.64it/s, dice_loss - 0.05819, RNLoss - 0.0, iou_score - 0.8931]
#
# Epoch: 4
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.04458, RNLoss - 0.06352, iou_score - 0.918]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.39it/s, dice_loss - 0.05832, RNLoss - 0.0, iou_score - 0.8928]
#
# Epoch: 5
# train: 100%|██████████| 37/37 [00:16<00:00,  2.18it/s, dice_loss - 0.04495, RNLoss - 0.06198, iou_score - 0.9174]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.36it/s, dice_loss - 0.05809, RNLoss - 0.0, iou_score - 0.8933]
#
# Epoch: 6
# train: 100%|██████████| 37/37 [00:16<00:00,  2.20it/s, dice_loss - 0.04476, RNLoss - 0.06779, iou_score - 0.9175]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.14it/s, dice_loss - 0.05798, RNLoss - 0.0, iou_score - 0.8935]
#
# Epoch: 7
# train: 100%|██████████| 37/37 [00:16<00:00,  2.19it/s, dice_loss - 0.04687, RNLoss - 0.04045, iou_score - 0.9138]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.19it/s, dice_loss - 0.05834, RNLoss - 0.0, iou_score - 0.8928]
#
# Epoch: 8
# train: 100%|██████████| 37/37 [00:17<00:00,  2.17it/s, dice_loss - 0.04472, RNLoss - 0.05949, iou_score - 0.9178]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.55it/s, dice_loss - 0.05814, RNLoss - 0.0, iou_score - 0.8932]
#
# Epoch: 9
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.04473, RNLoss - 0.03868, iou_score - 0.9178]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.90it/s, dice_loss - 0.05795, RNLoss - 0.0, iou_score - 0.8934]
#
# Epoch: 10
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.04453, RNLoss - 0.05675, iou_score - 0.918]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.75it/s, dice_loss - 0.05815, RNLoss - 0.0, iou_score - 0.8931]
#
# Epoch: 11
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.04528, RNLoss - 0.08771, iou_score - 0.9167]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.83it/s, dice_loss - 0.05815, RNLoss - 0.0, iou_score - 0.8931]
#
# Epoch: 12
# train: 100%|██████████| 37/37 [00:16<00:00,  2.19it/s, dice_loss - 0.04449, RNLoss - 0.0, iou_score - 0.9182]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.42it/s, dice_loss - 0.05829, RNLoss - 0.0, iou_score - 0.8929]
#
# Epoch: 13
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.04431, RNLoss - 0.01186, iou_score - 0.9183]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.13it/s, dice_loss - 0.05806, RNLoss - 0.0, iou_score - 0.8933]
#
# Epoch: 14
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.0444, RNLoss - 0.04501, iou_score - 0.9182]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.53it/s, dice_loss - 0.05788, RNLoss - 0.0, iou_score - 0.8936]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.0444, RNLoss - 0.02605, iou_score - 0.9185]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.60it/s, dice_loss - 0.05792, RNLoss - 0.0, iou_score - 0.8935]
#
# Epoch: 16
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.04356, RNLoss - 0.04347, iou_score - 0.9197]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.64it/s, dice_loss - 0.05814, RNLoss - 0.0, iou_score - 0.893]
#
# Epoch: 17
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.04425, RNLoss - 0.04868, iou_score - 0.9185]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.84it/s, dice_loss - 0.05793, RNLoss - 0.0, iou_score - 0.8934]
#
# Epoch: 18
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04398, RNLoss - 0.008297, iou_score - 0.9192]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.32it/s, dice_loss - 0.0581, RNLoss - 0.0, iou_score - 0.8932]
#
# Epoch: 19
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.04464, RNLoss - 0.1126, iou_score - 0.9177]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.10it/s, dice_loss - 0.05799, RNLoss - 0.0, iou_score - 0.8934]
#
# Epoch: 20
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.04511, RNLoss - 0.02942, iou_score - 0.9168]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.30it/s, dice_loss - 0.05803, RNLoss - 0.0, iou_score - 0.8933]
#
# Epoch: 21
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04331, RNLoss - 0.06839, iou_score - 0.9199]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.86it/s, dice_loss - 0.05823, RNLoss - 0.0, iou_score - 0.893]
#
# Epoch: 22
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04273, RNLoss - 0.04647, iou_score - 0.9213]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.80it/s, dice_loss - 0.05823, RNLoss - 0.0, iou_score - 0.8929]
#
# Epoch: 23
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04361, RNLoss - 0.02712, iou_score - 0.9196]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.05it/s, dice_loss - 0.05813, RNLoss - 0.0, iou_score - 0.8931]
#
# Epoch: 24
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04438, RNLoss - 0.07467, iou_score - 0.9181]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.19it/s, dice_loss - 0.05825, RNLoss - 0.0, iou_score - 0.8929]
#
# Epoch: 25
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.04411, RNLoss - 0.01957, iou_score - 0.9189]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.73it/s, dice_loss - 0.05803, RNLoss - 0.0, iou_score - 0.8932]
# Decrease decoder learning rate to 1e-5
#
# Epoch: 26
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04426, RNLoss - 0.05403, iou_score - 0.9183]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.23it/s, dice_loss - 0.05795, RNLoss - 0.0, iou_score - 0.8934]
#
# Epoch: 27
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04392, RNLoss - 0.04481, iou_score - 0.9189]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.73it/s, dice_loss - 0.05789, RNLoss - 0.0, iou_score - 0.8935]
#
# Epoch: 28
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04331, RNLoss - 0.05873, iou_score - 0.9199]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.87it/s, dice_loss - 0.05845, RNLoss - 0.0, iou_score - 0.8924]
#
# Epoch: 29
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.04339, RNLoss - 0.01188, iou_score - 0.9198]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.34it/s, dice_loss - 0.05797, RNLoss - 0.0, iou_score - 0.8933]
#
# Epoch: 30
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.04376, RNLoss - 0.02779, iou_score - 0.9193]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.64it/s, dice_loss - 0.05794, RNLoss - 0.0, iou_score - 0.8934]
#
# Epoch: 31
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04365, RNLoss - 0.09856, iou_score - 0.9198]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.93it/s, dice_loss - 0.05765, RNLoss - 0.0, iou_score - 0.8939]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.04398, RNLoss - 0.106, iou_score - 0.9189]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.08it/s, dice_loss - 0.05802, RNLoss - 0.0, iou_score - 0.8932]
#
# Epoch: 33
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04417, RNLoss - 0.03822, iou_score - 0.9184]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.22it/s, dice_loss - 0.05804, RNLoss - 0.0, iou_score - 0.8932]
#
# Epoch: 34
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.04377, RNLoss - 0.1049, iou_score - 0.9192]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.91it/s, dice_loss - 0.05774, RNLoss - 0.0, iou_score - 0.8937]
#
# Epoch: 35
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.04353, RNLoss - 0.09693, iou_score - 0.9195]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.19it/s, dice_loss - 0.05783, RNLoss - 0.0, iou_score - 0.8936]
#
# Epoch: 36
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.0435, RNLoss - 0.03722, iou_score - 0.9197]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.13it/s, dice_loss - 0.05782, RNLoss - 0.0, iou_score - 0.8936]
#
# Epoch: 37
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.04445, RNLoss - 0.02029, iou_score - 0.9179]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.87it/s, dice_loss - 0.05809, RNLoss - 0.0, iou_score - 0.8931]
#
# Epoch: 38
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04376, RNLoss - 0.05303, iou_score - 0.9191]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.42it/s, dice_loss - 0.05795, RNLoss - 0.0, iou_score - 0.8933]
#
# Epoch: 39
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.04465, RNLoss - 0.03611, iou_score - 0.9175]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.18it/s, dice_loss - 0.05802, RNLoss - 0.0, iou_score - 0.8932]
#
# Epoch: 40
# train: 100%|██████████| 37/37 [00:17<00:00,  2.17it/s, dice_loss - 0.04391, RNLoss - 0.1192, iou_score - 0.9189]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.88it/s, dice_loss - 0.05805, RNLoss - 0.0, iou_score - 0.8931]
#
# Epoch: 41
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04374, RNLoss - 0.01719, iou_score - 0.9191]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.21it/s, dice_loss - 0.05823, RNLoss - 0.0, iou_score - 0.8928]
#
# Epoch: 42
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.04291, RNLoss - 0.05736, iou_score - 0.9207]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.37it/s, dice_loss - 0.05807, RNLoss - 0.0, iou_score - 0.893]
#
# Epoch: 43
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04268, RNLoss - 0.05764, iou_score - 0.921]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.51it/s, dice_loss - 0.0578, RNLoss - 0.0, iou_score - 0.8935]
#
# Epoch: 44
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.04268, RNLoss - 0.04042, iou_score - 0.921]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.25it/s, dice_loss - 0.05783, RNLoss - 0.0, iou_score - 0.8936]
#
# Epoch: 45
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04462, RNLoss - 0.01767, iou_score - 0.9176]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.26it/s, dice_loss - 0.05761, RNLoss - 0.0, iou_score - 0.8938]
#
# Epoch: 46
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.04239, RNLoss - 0.008575, iou_score - 0.9217]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.12it/s, dice_loss - 0.05783, RNLoss - 0.0, iou_score - 0.8934]
#
# Epoch: 47
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.04222, RNLoss - 0.09769, iou_score - 0.9219]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.38it/s, dice_loss - 0.05783, RNLoss - 0.0, iou_score - 0.8935]
#
# Epoch: 48
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.0437, RNLoss - 0.05097, iou_score - 0.9192]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.87it/s, dice_loss - 0.05772, RNLoss - 0.0, iou_score - 0.8936]
#
# Epoch: 49
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.04313, RNLoss - 0.07261, iou_score - 0.9202]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.46it/s, dice_loss - 0.05773, RNLoss - 0.0, iou_score - 0.8936]

# %%
import matplotlib.pyplot as plt
import matplotlib
import pylab as py
matplotlib.rcParams.update({                      # setup matplotlib to use latex for output
        "pgf.texsystem": "pdflatex",              # change this if using xetex or lautex
        "text.usetex": True,                      # use LaTeX to write all text
        "figure.figsize": (9, 5),                 # default fig size of 0.9 textwidth
        "figure.dpi": 300,
        "font.family": "serif",
        "font.serif": [],                         # blank entries should cause plots to inherit fonts from the document
        "font.sans-serif": [],
        "font.monospace": [],
        "axes.labelsize": 20,                     # LaTeX default is 10pt font.
        'axes.titlesize': 15,
        "font.size": 15,
        "legend.fontsize": 20,                    # Make the legend/label fonts a little smaller
        "xtick.labelsize": 16,
        "ytick.labelsize": 16,
        })

# %%
# Train

fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(conv_train['iou'], label='IoU Score')
plt.plot(conv_train['dice'], label='Dice Loss')
plt.plot(conv_train['RN'], label='RN Loss')
plt.plot(np.arange(200), np.ones(200), 'k--')
plt.xlabel('Epoch')
plt.ylabel('Percent')
py.legend(loc='upper right')
plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### Iterator for Test Data

# %%
best_model = torch.load('saved_models/best_model_random_lambda_0pt001.pth')

test_epoch = ValidEpoch(
    model=best_model,
    loss = loss,
    metrics = metrics,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 0.001,
)

# %%
test_log = test_epoch.run(test_loader)
print('IOU Score: {}'.format(test_log['iou_score']))
# Out:
# valid: 100%|██████████| 99/99 [00:08<00:00, 11.62it/s, dice_loss - 0.0599, RNLoss - 0.0, iou_score - 0.8898]
# IOU Score: 0.8897605387851445

# %%
test_dataset_viz = Dataset(
    x_test_dir,
    masks_dir=None,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing_unlabeled(preprocessing_fn),
    classes = CLASSES,
)

# %%
num_test_img = len(test_dataset)

# %%
image_viz, mask_viz = test_dataset_viz[0]
image, mask = test_dataset[0]
img_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
pred_mask = best_model.predict(img_tensor)
pred_mask = pred_mask.squeeze().cpu().numpy().round()
plt.imshow(get_color_img(pred_mask, normal=False))
plt.title('Prediction')
plt.show()
plt.imshow(get_color_img(mask, normal=False))
plt.title('Ground-Truth')
plt.show()

# %%
from scripts.dorsal_to import explicit_dorsal_to_nobatch, rn_dorsal_to_nobatch

x_unlabeled_test_dir = '/raid/maruf/inhs-800/img_crp/'
test_dataset_unlabeled = Dataset(
    x_unlabeled_test_dir,
    masks_dir=None,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing_unlabeled(preprocessing_fn),
    classes = CLASSES,
)
test_loader_unlabeled = DataLoader(test_dataset_unlabeled, batch_size=1)
num_test_img = len(test_dataset_unlabeled)
unlabeled_inconsistency = 0
for test_no in range(num_test_img):
    image, mask = test_dataset_unlabeled[test_no]
    img_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
    pred_mask = best_model.predict(img_tensor)
    pred_mask = pred_mask.squeeze().cpu().numpy().round()
    unlabeled_inconsistency += explicit_dorsal_to_nobatch(labelmap=pred_mask, tensor=False)
    
    if test_no == 1000:
        break
    if test_no % 100 == 0:
        print('\n',test_no, 'done!\n')
    else:
        print('.', end='')
print('Unlabeled Inconsistency for {} model: {}'.format('SM_RN_lam_0.001', unlabeled_inconsistency))
# Out:
#  0 done!
#
# ...................................................................................................
#  100 done!
#
# ...................................................................................................
#  200 done!
#
# ...................................................................................................
#  300 done!
#
# ...................................................................................................
#  400 done!
#
# ...................................................................................................
#  500 done!
#
# ...................................................................................................
#  600 done!
#
# ...................................................................................................
#  700 done!
#
# ...................................................................................................
#  800 done!
#
# ...................................................................................................
#  900 done!
#
# ...................................................................................................Unlabeled Inconsistency for SM_RN_lam_0.001 model: 5.0
