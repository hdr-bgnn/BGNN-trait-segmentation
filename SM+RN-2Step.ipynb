# %% [raw]
# '''
# This notebook contains the general training module to train the segmentation model.
# The supervision is guided by the ground-truth segmentation labels and the prediction consistency
# of RN. At first, we will only use dorsal-to RN to evaluate the prediction performance.
# '''

# %%
# %matplotlib inline
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image

from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

import torch
import segmentation_models_pytorch as smp
import albumentations as albu

import seaborn as sns
import pylab as py
import pandas as pd

from scripts.preprocessing import Dataset
from scripts.helper import plot_double_image, plot_triple_image, get_color_img, get_concat_h
from scripts.augmentation import get_training_augmentation, get_validation_augmentation, to_tensor, get_preprocessing, get_preprocessing_unlabeled

DEVICE = ('cuda:2' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# #### Directories

# %%
##### Assign the location of your datasets

DATA_DIR = '/raid/maruf/data-800/'
# train set
x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'trainannot')
# validation set
x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'valannot')
# test set
x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'testannot')

# %% [markdown]
# #### Pretrained Model

# %%
# encoder: resnext50
# encoder weights: imagenet
# segmentation model: FPN 

ENCODER = 'se_resnext50_32x4d'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = ['dorsal', 'adipose', 'caudal', 'anal', 
           'pelvic', 'pectoral', 'head', 'eye', 
           'caudal-ray', 'alt-ray', 'alt-spine', 'trunk']
ACTIVATION = 'sigmoid'
# segmentation model with pretrained encoder
model = smp.FPN(
    encoder_name = ENCODER,
    encoder_weights = ENCODER_WEIGHTS,
    classes = len(CLASSES),
    activation = ACTIVATION,
)
# preprocessing function for this encoder
preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)

# %% [markdown]
# #### Dataset and Dataloader

# %%
train_dataset = Dataset(
    x_train_dir,
    y_train_dir,
    augmentation = get_training_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    classes = CLASSES,
)

valid_dataset = Dataset(
    x_valid_dir,
    y_valid_dir,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    classes = CLASSES,
)

test_dataset = Dataset(
    x_test_dir,
    y_test_dir,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing(preprocessing_fn),
    classes = CLASSES,
)

# loading data from the dataset
train_loader = DataLoader(train_dataset, batch_size = 8, shuffle=True, num_workers = 12)
valid_loader = DataLoader(valid_dataset, batch_size = 1, shuffle=False, num_workers = 4)
test_loader = DataLoader(test_dataset)

# %% [markdown]
# #### Optimizer, Loss and Metrics

# %%
# optimizers
optimizer = torch.optim.Adam([
    dict(params = model.parameters(), lr = 0.0001),
])

# loss = dice lose, metric = iou_score
loss = smp.utils.losses.DiceLoss()
metrics = [
    smp.utils.metrics.IoU(threshold=0.5)
]

# %%
# load RN model
from scripts.RN import RN
rn_model = RN().to(DEVICE)
rn_model.load_state_dict(torch.load('saved_models/rn_model.pt'))
rn_loss = torch.nn.BCELoss()

# %% [markdown]
# #### Iterators for Dataloaders

# %%
from scripts.utils.train import TrainEpoch, ValidEpoch

train_epoch = TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 0.,
)

valid_epoch = ValidEpoch(
    model,
    loss = loss,
    metrics = metrics,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 0.,
)

# %% [markdown]
# #### Training

# %%
# # We will train the model for 120 epochs
number_epoch = 10
max_score = 0

conv_train = {'dice': [],
              'RN': [],
              'iou': [],}
conv_valid = {'dice': [],
              'RN': [],
              'iou': [],}

for i in range(0, number_epoch):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)
    
    # to save model
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, 'saved_models/best_model_random_lambda_01.pth')
        print('Model saved!')
        
    # step wise loss function
    # lr changed after 25 epochs
    
    conv_train['dice'].append(train_logs['dice_loss'])    
    conv_train['RN'].append(train_logs['RNLoss'])     
    conv_train['iou'].append(train_logs['iou_score'])
    
    conv_valid['dice'].append(valid_logs['dice_loss'])    
    conv_valid['RN'].append(valid_logs['RNLoss'])     
    conv_valid['iou'].append(valid_logs['iou_score'])
    
    
    if i == 25:
        optimizer.param_groups[0]['lr'] = 1e-5
        print('Decrease decoder learning rate to 1e-5')
        
    if i % 10 == 0:
        image, mask = test_dataset[0]
        img_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
        pred_mask = model.predict(img_tensor)
        pred_mask = pred_mask.squeeze().cpu().numpy().round()
        if os.path.exists('Segmentations/SM_RN_2S/epoch_'+str(i)+'/') is False:
            os.makedirs('Segmentations/SM_RN_2S/epoch_'+str(i)+'/')
        get_color_img(pred_mask, normal=False).save('Segmentations/SM_RN_2S/epoch_'+str(i)+'/prediction.png')
        # write the scores
        
        with open('Segmentations/SM_RN_2S/epoch_'+str(i)+'/scores.txt', 'w+') as f:
            f.write('dice_loss:'+str(train_logs['dice_loss'])+'\n')
            f.write('RNLoss:'+str(train_logs['RNLoss'])+'\n')
            f.write('iou_score:'+str(train_logs['iou_score'])+'\n')
# Out:
# Epoch: 0
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.6488, RNLoss - 4.167, iou_score - 0.2885]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.43it/s, dice_loss - 0.2678, RNLoss - 0.07241, iou_score - 0.6551]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 37/37 [00:16<00:00,  2.21it/s, dice_loss - 0.2785, RNLoss - 0.8599, iou_score - 0.6726]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.92it/s, dice_loss - 0.1643, RNLoss - 0.02305, iou_score - 0.7586]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.1955, RNLoss - 0.4953, iou_score - 0.7462]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.75it/s, dice_loss - 0.1377, RNLoss - 0.0, iou_score - 0.7875]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1602, RNLoss - 0.1805, iou_score - 0.7847]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.63it/s, dice_loss - 0.1239, RNLoss - 0.0, iou_score - 0.8053]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1416, RNLoss - 0.2002, iou_score - 0.803]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.14it/s, dice_loss - 0.1048, RNLoss - 0.0, iou_score - 0.8331]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.129, RNLoss - 0.3371, iou_score - 0.813]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.83it/s, dice_loss - 0.1026, RNLoss - 0.0, iou_score - 0.8337]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 37/37 [00:17<00:00,  2.17it/s, dice_loss - 0.1177, RNLoss - 0.2009, iou_score - 0.8282]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.67it/s, dice_loss - 0.08791, RNLoss - 0.0, iou_score - 0.8573]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.09666, RNLoss - 0.0219, iou_score - 0.8569]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.38it/s, dice_loss - 0.0811, RNLoss - 0.0, iou_score - 0.8661]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.08948, RNLoss - 0.1092, iou_score - 0.8664]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.77it/s, dice_loss - 0.07625, RNLoss - 0.0, iou_score - 0.8734]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.08932, RNLoss - 0.06193, iou_score - 0.8677]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.00it/s, dice_loss - 0.07309, RNLoss - 0.0, iou_score - 0.8779]
# Model saved!

# %%
from scripts.utils.train import TrainEpoch, ValidEpoch

train_epoch = TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 1.,
)

valid_epoch = ValidEpoch(
    model,
    loss = loss,
    metrics = metrics,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 1.,
)

# %%
# # We will train the model for 120 epochs
number_epoch = 180
max_score = 0

conv_train = {'dice': [],
              'RN': [],
              'iou': [],}
conv_valid = {'dice': [],
              'RN': [],
              'iou': [],}

for i in range(0, number_epoch):
    
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(train_loader)
    valid_logs = valid_epoch.run(valid_loader)
    
    # to save model
    if max_score < valid_logs['iou_score']:
        max_score = valid_logs['iou_score']
        torch.save(model, 'saved_models/best_model_random_lambda_01.pth')
        print('Model saved!')
        
    # step wise loss function
    # lr changed after 25 epochs
    
    conv_train['dice'].append(train_logs['dice_loss'])    
    conv_train['RN'].append(train_logs['RNLoss'])     
    conv_train['iou'].append(train_logs['iou_score'])
    
    conv_valid['dice'].append(valid_logs['dice_loss'])    
    conv_valid['RN'].append(valid_logs['RNLoss'])     
    conv_valid['iou'].append(valid_logs['iou_score'])
    
    
    if i == 25:
        optimizer.param_groups[0]['lr'] = 1e-5
        print('Decrease decoder learning rate to 1e-5')
        
    if i % 10 == 0:
        image, mask = test_dataset[0]
        img_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
        pred_mask = model.predict(img_tensor)
        pred_mask = pred_mask.squeeze().cpu().numpy().round()
        if os.path.exists('Segmentations/SM_RN_2S/epoch_'+str(i+11)+'/') is False:
            os.makedirs('Segmentations/SM_RN_2S/epoch_'+str(i+11)+'/')
        get_color_img(pred_mask, normal=False).save('Segmentations/SM_RN_2S/epoch_'+str(i+11)+'/prediction.png')
        # write the scores
        
        with open('Segmentations/SM_RN_2S/epoch_'+str(i+11)+'/scores.txt', 'w+') as f:
            f.write('dice_loss:'+str(train_logs['dice_loss'])+'\n')
            f.write('RNLoss:'+str(train_logs['RNLoss'])+'\n')
            f.write('iou_score:'+str(train_logs['iou_score'])+'\n')
# Out:
# Epoch: 0
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.08439, RNLoss - 0.000194, iou_score - 0.8692]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.46it/s, dice_loss - 0.07528, RNLoss - 0.0, iou_score - 0.8734]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.08501, RNLoss - 0.004544, iou_score - 0.8653]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.14it/s, dice_loss - 0.09909, RNLoss - 0.0, iou_score - 0.8323]
#
# Epoch: 2
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1235, RNLoss - 0.04847, iou_score - 0.8048]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.11it/s, dice_loss - 0.1236, RNLoss - 0.0, iou_score - 0.8004]
#
# Epoch: 3
# train: 100%|██████████| 37/37 [00:17<00:00,  2.17it/s, dice_loss - 0.1717, RNLoss - 0.1021, iou_score - 0.7389]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.03it/s, dice_loss - 0.1827, RNLoss - 0.0, iou_score - 0.7134]
#
# Epoch: 4
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.2536, RNLoss - 0.09193, iou_score - 0.6301]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.71it/s, dice_loss - 0.3134, RNLoss - 0.0, iou_score - 0.5438]
#
# Epoch: 5
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.2719, RNLoss - 0.02071, iou_score - 0.6056]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.53it/s, dice_loss - 0.2231, RNLoss - 0.0, iou_score - 0.6647]
#
# Epoch: 6
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.2311, RNLoss - 0.001583, iou_score - 0.6616]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.97it/s, dice_loss - 0.1738, RNLoss - 0.0, iou_score - 0.7236]
#
# Epoch: 7
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.178, RNLoss - 0.0, iou_score - 0.728]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.48it/s, dice_loss - 0.1489, RNLoss - 0.0, iou_score - 0.7564]
#
# Epoch: 8
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.182, RNLoss - 0.06864, iou_score - 0.7194]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.65it/s, dice_loss - 0.3158, RNLoss - 0.0, iou_score - 0.5367]
#
# Epoch: 9
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.3253, RNLoss - 0.04163, iou_score - 0.5324]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.95it/s, dice_loss - 0.3216, RNLoss - 0.0, iou_score - 0.5291]
#
# Epoch: 10
# train: 100%|██████████| 37/37 [00:17<00:00,  2.16it/s, dice_loss - 0.2789, RNLoss - 0.0, iou_score - 0.5864]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.54it/s, dice_loss - 0.2311, RNLoss - 0.0, iou_score - 0.641]
#
# Epoch: 11
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.2178, RNLoss - 0.0, iou_score - 0.6642]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.78it/s, dice_loss - 0.1882, RNLoss - 0.0, iou_score - 0.6976]
#
# Epoch: 12
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1885, RNLoss - 0.0, iou_score - 0.7053]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.45it/s, dice_loss - 0.1582, RNLoss - 0.0, iou_score - 0.74]
#
# Epoch: 13
# train: 100%|██████████| 37/37 [00:17<00:00,  2.16it/s, dice_loss - 0.1973, RNLoss - 0.03867, iou_score - 0.6933]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.76it/s, dice_loss - 0.179, RNLoss - 0.0, iou_score - 0.7154]
#
# Epoch: 14
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1916, RNLoss - 0.0009468, iou_score - 0.6999]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.30it/s, dice_loss - 0.1674, RNLoss - 0.0, iou_score - 0.731]
#
# Epoch: 15
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1802, RNLoss - 0.0, iou_score - 0.7143]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.19it/s, dice_loss - 0.156, RNLoss - 0.0, iou_score - 0.7469]
#
# Epoch: 16
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1695, RNLoss - 0.0, iou_score - 0.7288]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.73it/s, dice_loss - 0.1501, RNLoss - 0.0, iou_score - 0.755]
#
# Epoch: 17
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1675, RNLoss - 0.0, iou_score - 0.733]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.16it/s, dice_loss - 0.1444, RNLoss - 0.0, iou_score - 0.7624]
#
# Epoch: 18
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1576, RNLoss - 0.0, iou_score - 0.7434]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.78it/s, dice_loss - 0.1408, RNLoss - 0.0, iou_score - 0.7672]
#
# Epoch: 19
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.1622, RNLoss - 0.04281, iou_score - 0.736]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.84it/s, dice_loss - 0.171, RNLoss - 0.0, iou_score - 0.7209]
#
# Epoch: 20
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.2095, RNLoss - 0.0001462, iou_score - 0.671]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.59it/s, dice_loss - 0.2023, RNLoss - 0.0, iou_score - 0.676]
#
# Epoch: 21
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1934, RNLoss - 0.0, iou_score - 0.6942]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.02it/s, dice_loss - 0.1706, RNLoss - 0.0, iou_score - 0.7203]
#
# Epoch: 22
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1761, RNLoss - 0.06041, iou_score - 0.7153]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.92it/s, dice_loss - 0.1635, RNLoss - 0.0, iou_score - 0.73]
#
# Epoch: 23
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.1746, RNLoss - 0.03092, iou_score - 0.7163]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.56it/s, dice_loss - 0.1582, RNLoss - 0.0, iou_score - 0.7394]
#
# Epoch: 24
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1757, RNLoss - 0.0, iou_score - 0.7165]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.44it/s, dice_loss - 0.1451, RNLoss - 0.0, iou_score - 0.7592]
#
# Epoch: 25
# train: 100%|██████████| 37/37 [00:17<00:00,  2.16it/s, dice_loss - 0.16, RNLoss - 0.0, iou_score - 0.7392]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.44it/s, dice_loss - 0.1406, RNLoss - 0.0, iou_score - 0.7656]
# Decrease decoder learning rate to 1e-5
#
# Epoch: 26
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1579, RNLoss - 0.0, iou_score - 0.7431]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.01it/s, dice_loss - 0.1405, RNLoss - 0.0, iou_score - 0.7652]
#
# Epoch: 27
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1589, RNLoss - 0.03719, iou_score - 0.7405]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.97it/s, dice_loss - 0.14, RNLoss - 0.0, iou_score - 0.7663]
#
# Epoch: 28
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1573, RNLoss - 0.0, iou_score - 0.7432]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.27it/s, dice_loss - 0.1383, RNLoss - 0.0, iou_score - 0.7686]
#
# Epoch: 29
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1575, RNLoss - 0.0, iou_score - 0.7424]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.40it/s, dice_loss - 0.1387, RNLoss - 0.0, iou_score - 0.7681]
#
# Epoch: 30
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1563, RNLoss - 0.0, iou_score - 0.7425]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.55it/s, dice_loss - 0.138, RNLoss - 0.0, iou_score - 0.769]
#
# Epoch: 31
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1594, RNLoss - 0.0, iou_score - 0.7396]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.58it/s, dice_loss - 0.138, RNLoss - 0.0, iou_score - 0.7688]
#
# Epoch: 32
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.158, RNLoss - 0.032, iou_score - 0.7406]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.80it/s, dice_loss - 0.1382, RNLoss - 0.0, iou_score - 0.7687]
#
# Epoch: 33
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.156, RNLoss - 0.06063, iou_score - 0.7435]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.30it/s, dice_loss - 0.1419, RNLoss - 0.0, iou_score - 0.7631]
#
# Epoch: 34
# train: 100%|██████████| 37/37 [00:16<00:00,  2.19it/s, dice_loss - 0.1559, RNLoss - 0.00725, iou_score - 0.7443]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.17it/s, dice_loss - 0.1402, RNLoss - 0.0, iou_score - 0.7654]
#
# Epoch: 35
# train: 100%|██████████| 37/37 [00:16<00:00,  2.18it/s, dice_loss - 0.1566, RNLoss - 0.0, iou_score - 0.7422]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.72it/s, dice_loss - 0.1405, RNLoss - 0.0, iou_score - 0.7649]
#
# Epoch: 36
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1562, RNLoss - 0.002902, iou_score - 0.7428]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.90it/s, dice_loss - 0.1411, RNLoss - 0.0, iou_score - 0.7639]
#
# Epoch: 37
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1551, RNLoss - 0.0, iou_score - 0.7442]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.94it/s, dice_loss - 0.1403, RNLoss - 0.0, iou_score - 0.7651]
#
# Epoch: 38
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1559, RNLoss - 0.0, iou_score - 0.7432]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.23it/s, dice_loss - 0.1402, RNLoss - 0.0, iou_score - 0.7652]
#
# Epoch: 39
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1567, RNLoss - 0.0006646, iou_score - 0.7426]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.05it/s, dice_loss - 0.139, RNLoss - 0.0, iou_score - 0.7669]
#
# Epoch: 40
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1543, RNLoss - 0.0, iou_score - 0.7461]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.78it/s, dice_loss - 0.1392, RNLoss - 0.0, iou_score - 0.7666]
#
# Epoch: 41
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1499, RNLoss - 0.0, iou_score - 0.7514]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.15it/s, dice_loss - 0.1383, RNLoss - 0.0, iou_score - 0.7682]
#
# Epoch: 42
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1541, RNLoss - 0.0, iou_score - 0.7463]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.13it/s, dice_loss - 0.1375, RNLoss - 0.0, iou_score - 0.7692]
#
# Epoch: 43
# train: 100%|██████████| 37/37 [00:17<00:00,  2.17it/s, dice_loss - 0.1529, RNLoss - 0.0, iou_score - 0.7475]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.89it/s, dice_loss - 0.1373, RNLoss - 0.0, iou_score - 0.7694]
#
# Epoch: 44
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.153, RNLoss - 0.0, iou_score - 0.7469]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.97it/s, dice_loss - 0.137, RNLoss - 0.0, iou_score - 0.77]
#
# Epoch: 45
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.149, RNLoss - 0.0, iou_score - 0.7528]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.46it/s, dice_loss - 0.1361, RNLoss - 0.0, iou_score - 0.7715]
#
# Epoch: 46
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1501, RNLoss - 0.02898, iou_score - 0.7521]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.66it/s, dice_loss - 0.1349, RNLoss - 0.0, iou_score - 0.7731]
#
# Epoch: 47
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1541, RNLoss - 0.0161, iou_score - 0.7456]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.25it/s, dice_loss - 0.1349, RNLoss - 0.0, iou_score - 0.7732]
#
# Epoch: 48
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1491, RNLoss - 0.0, iou_score - 0.7525]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.04it/s, dice_loss - 0.1342, RNLoss - 0.0, iou_score - 0.7743]
#
# Epoch: 49
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1507, RNLoss - 0.0, iou_score - 0.7508]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.16it/s, dice_loss - 0.134, RNLoss - 0.0, iou_score - 0.7747]
#
# Epoch: 50
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1485, RNLoss - 0.03713, iou_score - 0.7528]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.47it/s, dice_loss - 0.1338, RNLoss - 0.0, iou_score - 0.775]
#
# Epoch: 51
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1524, RNLoss - 0.0, iou_score - 0.7482]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.79it/s, dice_loss - 0.1341, RNLoss - 0.0, iou_score - 0.7744]
#
# Epoch: 52
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1497, RNLoss - 0.002502, iou_score - 0.7526]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.95it/s, dice_loss - 0.1351, RNLoss - 0.0, iou_score - 0.7728]
#
# Epoch: 53
# train: 100%|██████████| 37/37 [00:18<00:00,  2.01it/s, dice_loss - 0.1544, RNLoss - 0.007403, iou_score - 0.745]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.73it/s, dice_loss - 0.1342, RNLoss - 0.0, iou_score - 0.7745]
#
# Epoch: 54
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1503, RNLoss - 0.028, iou_score - 0.7513]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.18it/s, dice_loss - 0.1348, RNLoss - 0.0, iou_score - 0.7733]
#
# Epoch: 55
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1502, RNLoss - 0.0, iou_score - 0.751]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.62it/s, dice_loss - 0.1343, RNLoss - 0.0, iou_score - 0.7738]
#
# Epoch: 56
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1512, RNLoss - 0.0, iou_score - 0.75]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.37it/s, dice_loss - 0.134, RNLoss - 0.0, iou_score - 0.7744]
#
# Epoch: 57
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1498, RNLoss - 0.002126, iou_score - 0.7518]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.28it/s, dice_loss - 0.134, RNLoss - 0.0, iou_score - 0.7745]
#
# Epoch: 58
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1511, RNLoss - 0.0, iou_score - 0.7494]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.79it/s, dice_loss - 0.1334, RNLoss - 0.0, iou_score - 0.7759]
#
# Epoch: 59
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1491, RNLoss - 0.0, iou_score - 0.7527]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.95it/s, dice_loss - 0.1323, RNLoss - 0.0, iou_score - 0.777]
#
# Epoch: 60
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.15, RNLoss - 0.01223, iou_score - 0.751]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.83it/s, dice_loss - 0.1329, RNLoss - 0.0, iou_score - 0.7759]
#
# Epoch: 61
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1471, RNLoss - 0.02632, iou_score - 0.7551]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.18it/s, dice_loss - 0.133, RNLoss - 0.0, iou_score - 0.7757]
#
# Epoch: 62
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.148, RNLoss - 0.0, iou_score - 0.7538]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.37it/s, dice_loss - 0.1329, RNLoss - 0.0, iou_score - 0.776]
#
# Epoch: 63
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1469, RNLoss - 0.0, iou_score - 0.7556]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.04it/s, dice_loss - 0.1332, RNLoss - 0.0, iou_score - 0.776]
#
# Epoch: 64
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.148, RNLoss - 0.003703, iou_score - 0.7536]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.60it/s, dice_loss - 0.1323, RNLoss - 0.0, iou_score - 0.7771]
#
# Epoch: 65
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1461, RNLoss - 0.0, iou_score - 0.7569]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.07it/s, dice_loss - 0.1315, RNLoss - 0.0, iou_score - 0.7785]
#
# Epoch: 66
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1456, RNLoss - 0.0, iou_score - 0.7575]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.92it/s, dice_loss - 0.1321, RNLoss - 0.0, iou_score - 0.7771]
#
# Epoch: 67
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1415, RNLoss - 0.0, iou_score - 0.7633]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.74it/s, dice_loss - 0.1312, RNLoss - 0.0, iou_score - 0.7786]
#
# Epoch: 68
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1498, RNLoss - 0.01262, iou_score - 0.7521]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.19it/s, dice_loss - 0.1314, RNLoss - 0.0, iou_score - 0.7786]
#
# Epoch: 69
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1446, RNLoss - 0.0, iou_score - 0.7583]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.57it/s, dice_loss - 0.1311, RNLoss - 0.0, iou_score - 0.7788]
#
# Epoch: 70
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1447, RNLoss - 0.0, iou_score - 0.7582]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.64it/s, dice_loss - 0.131, RNLoss - 0.0, iou_score - 0.7788]
#
# Epoch: 71
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1435, RNLoss - 0.0, iou_score - 0.7602]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.66it/s, dice_loss - 0.1301, RNLoss - 0.0, iou_score - 0.7801]
#
# Epoch: 72
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1458, RNLoss - 0.0, iou_score - 0.7575]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.84it/s, dice_loss - 0.1299, RNLoss - 0.0, iou_score - 0.7802]
#
# Epoch: 73
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1423, RNLoss - 0.0, iou_score - 0.7622]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.21it/s, dice_loss - 0.1299, RNLoss - 0.0, iou_score - 0.7802]
#
# Epoch: 74
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1439, RNLoss - 0.0, iou_score - 0.7593]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.72it/s, dice_loss - 0.1297, RNLoss - 0.0, iou_score - 0.781]
#
# Epoch: 75
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1448, RNLoss - 0.0, iou_score - 0.7596]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.86it/s, dice_loss - 0.1293, RNLoss - 0.0, iou_score - 0.7813]
#
# Epoch: 76
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.1419, RNLoss - 0.0, iou_score - 0.7627]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.90it/s, dice_loss - 0.1288, RNLoss - 0.0, iou_score - 0.7822]
#
# Epoch: 77
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1418, RNLoss - 0.008817, iou_score - 0.763]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.75it/s, dice_loss - 0.1286, RNLoss - 0.0, iou_score - 0.7823]
#
# Epoch: 78
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1415, RNLoss - 0.0, iou_score - 0.7633]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.73it/s, dice_loss - 0.1287, RNLoss - 0.0, iou_score - 0.7823]
#
# Epoch: 79
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1402, RNLoss - 0.001034, iou_score - 0.7646]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.02it/s, dice_loss - 0.128, RNLoss - 0.0, iou_score - 0.7833]
#
# Epoch: 80
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1433, RNLoss - 0.0, iou_score - 0.7607]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.51it/s, dice_loss - 0.1279, RNLoss - 0.0, iou_score - 0.7834]
#
# Epoch: 81
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1435, RNLoss - 0.0, iou_score - 0.7602]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.70it/s, dice_loss - 0.1281, RNLoss - 0.0, iou_score - 0.7828]
#
# Epoch: 82
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1446, RNLoss - 0.004858, iou_score - 0.7583]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.62it/s, dice_loss - 0.1296, RNLoss - 0.0, iou_score - 0.7801]
#
# Epoch: 83
# train: 100%|██████████| 37/37 [00:18<00:00,  2.04it/s, dice_loss - 0.1388, RNLoss - 0.0, iou_score - 0.7666]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.87it/s, dice_loss - 0.1283, RNLoss - 0.0, iou_score - 0.7823]
#
# Epoch: 84
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1395, RNLoss - 0.0, iou_score - 0.766]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.87it/s, dice_loss - 0.1277, RNLoss - 0.0, iou_score - 0.7833]
#
# Epoch: 85
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1386, RNLoss - 0.06084, iou_score - 0.7673]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.61it/s, dice_loss - 0.1281, RNLoss - 0.0, iou_score - 0.7826]
#
# Epoch: 86
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1421, RNLoss - 0.01315, iou_score - 0.7619]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.14it/s, dice_loss - 0.1273, RNLoss - 0.0, iou_score - 0.7839]
#
# Epoch: 87
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1399, RNLoss - 0.0, iou_score - 0.7658]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.26it/s, dice_loss - 0.1274, RNLoss - 0.0, iou_score - 0.7835]
#
# Epoch: 88
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.1375, RNLoss - 0.0, iou_score - 0.7686]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.92it/s, dice_loss - 0.1268, RNLoss - 0.0, iou_score - 0.7849]
#
# Epoch: 89
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1392, RNLoss - 0.0, iou_score - 0.7664]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.33it/s, dice_loss - 0.1271, RNLoss - 0.0, iou_score - 0.7839]
#
# Epoch: 90
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1395, RNLoss - 0.0, iou_score - 0.7659]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.49it/s, dice_loss - 0.1262, RNLoss - 0.0, iou_score - 0.7851]
#
# Epoch: 91
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1398, RNLoss - 0.0, iou_score - 0.7653]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.24it/s, dice_loss - 0.1261, RNLoss - 0.0, iou_score - 0.7854]
#
# Epoch: 92
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.138, RNLoss - 0.0, iou_score - 0.768]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.81it/s, dice_loss - 0.1263, RNLoss - 0.0, iou_score - 0.785]
#
# Epoch: 93
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.1376, RNLoss - 0.0, iou_score - 0.7681]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.44it/s, dice_loss - 0.1263, RNLoss - 0.0, iou_score - 0.7853]
#
# Epoch: 94
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1374, RNLoss - 0.02912, iou_score - 0.7688]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.16it/s, dice_loss - 0.1251, RNLoss - 0.0, iou_score - 0.7869]
#
# Epoch: 95
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1413, RNLoss - 0.0008358, iou_score - 0.763]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.45it/s, dice_loss - 0.1249, RNLoss - 0.0, iou_score - 0.7872]
#
# Epoch: 96
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1395, RNLoss - 0.0, iou_score - 0.7653]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.90it/s, dice_loss - 0.1249, RNLoss - 0.0, iou_score - 0.7874]
#
# Epoch: 97
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1411, RNLoss - 0.0, iou_score - 0.7635]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.61it/s, dice_loss - 0.1248, RNLoss - 0.0, iou_score - 0.7875]
#
# Epoch: 98
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1389, RNLoss - 0.0, iou_score - 0.7664]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.72it/s, dice_loss - 0.1242, RNLoss - 0.0, iou_score - 0.7883]
#
# Epoch: 99
# train: 100%|██████████| 37/37 [00:17<00:00,  2.16it/s, dice_loss - 0.1444, RNLoss - 0.0, iou_score - 0.7589]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.83it/s, dice_loss - 0.1246, RNLoss - 0.0, iou_score - 0.7879]
#
# Epoch: 100
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1388, RNLoss - 0.0, iou_score - 0.766]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.02it/s, dice_loss - 0.124, RNLoss - 0.0, iou_score - 0.7886]
#
# Epoch: 101
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1393, RNLoss - 0.0, iou_score - 0.7664]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.02it/s, dice_loss - 0.1239, RNLoss - 0.0, iou_score - 0.7884]
#
# Epoch: 102
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1394, RNLoss - 0.0, iou_score - 0.7658]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.77it/s, dice_loss - 0.1236, RNLoss - 0.0, iou_score - 0.7892]
#
# Epoch: 103
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1362, RNLoss - 0.0, iou_score - 0.7696]
# valid: 100%|██████████| 98/98 [00:04<00:00, 22.15it/s, dice_loss - 0.1243, RNLoss - 0.0, iou_score - 0.788]
#
# Epoch: 104
# train: 100%|██████████| 37/37 [00:18<00:00,  2.03it/s, dice_loss - 0.1384, RNLoss - 0.0, iou_score - 0.7668]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.00it/s, dice_loss - 0.124, RNLoss - 0.0, iou_score - 0.7885]
#
# Epoch: 105
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1353, RNLoss - 0.0, iou_score - 0.7716]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.03it/s, dice_loss - 0.1238, RNLoss - 0.0, iou_score - 0.7889]
#
# Epoch: 106
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1373, RNLoss - 0.0, iou_score - 0.7689]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.15it/s, dice_loss - 0.1234, RNLoss - 0.0, iou_score - 0.7896]
#
# Epoch: 107
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1378, RNLoss - 0.0, iou_score - 0.7682]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.56it/s, dice_loss - 0.1233, RNLoss - 0.0, iou_score - 0.7893]
#
# Epoch: 108
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1372, RNLoss - 0.0, iou_score - 0.7683]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.49it/s, dice_loss - 0.1234, RNLoss - 0.0, iou_score - 0.7893]
#
# Epoch: 109
# train: 100%|██████████| 37/37 [00:18<00:00,  2.03it/s, dice_loss - 0.1359, RNLoss - 0.0, iou_score - 0.7711]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.74it/s, dice_loss - 0.1229, RNLoss - 0.0, iou_score - 0.7901]
#
# Epoch: 110
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1341, RNLoss - 0.0, iou_score - 0.7736]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.24it/s, dice_loss - 0.1232, RNLoss - 0.0, iou_score - 0.7896]
#
# Epoch: 111
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.133, RNLoss - 0.0, iou_score - 0.7751]
# valid: 100%|██████████| 98/98 [00:04<00:00, 22.51it/s, dice_loss - 0.123, RNLoss - 0.0, iou_score - 0.79]
#
# Epoch: 112
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1345, RNLoss - 0.0, iou_score - 0.7725]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.65it/s, dice_loss - 0.1228, RNLoss - 0.0, iou_score - 0.7901]
#
# Epoch: 113
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1339, RNLoss - 0.0, iou_score - 0.7732]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.59it/s, dice_loss - 0.1229, RNLoss - 0.0, iou_score - 0.79]
#
# Epoch: 114
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1323, RNLoss - 0.006706, iou_score - 0.7755]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.65it/s, dice_loss - 0.1234, RNLoss - 0.0, iou_score - 0.7893]
#
# Epoch: 115
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1322, RNLoss - 0.0, iou_score - 0.7752]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.67it/s, dice_loss - 0.1227, RNLoss - 0.0, iou_score - 0.7902]
#
# Epoch: 116
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1356, RNLoss - 0.0, iou_score - 0.771]
# valid: 100%|██████████| 98/98 [00:04<00:00, 22.68it/s, dice_loss - 0.1226, RNLoss - 0.0, iou_score - 0.7902]
#
# Epoch: 117
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1346, RNLoss - 0.0, iou_score - 0.7718]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.20it/s, dice_loss - 0.1219, RNLoss - 0.0, iou_score - 0.7914]
#
# Epoch: 118
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1357, RNLoss - 0.0, iou_score - 0.7703]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.96it/s, dice_loss - 0.1219, RNLoss - 0.0, iou_score - 0.7913]
#
# Epoch: 119
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1331, RNLoss - 0.03107, iou_score - 0.7744]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.01it/s, dice_loss - 0.1222, RNLoss - 0.0, iou_score - 0.791]
#
# Epoch: 120
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.1326, RNLoss - 0.0, iou_score - 0.7756]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.23it/s, dice_loss - 0.1221, RNLoss - 0.0, iou_score - 0.7911]
#
# Epoch: 121
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1314, RNLoss - 0.02043, iou_score - 0.7774]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.56it/s, dice_loss - 0.122, RNLoss - 0.0, iou_score - 0.7911]
#
# Epoch: 122
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1326, RNLoss - 0.0, iou_score - 0.7751]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.73it/s, dice_loss - 0.1224, RNLoss - 0.0, iou_score - 0.7909]
#
# Epoch: 123
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1328, RNLoss - 0.0, iou_score - 0.7747]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.85it/s, dice_loss - 0.1217, RNLoss - 0.0, iou_score - 0.7917]
#
# Epoch: 124
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1331, RNLoss - 0.0, iou_score - 0.7739]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.07it/s, dice_loss - 0.1215, RNLoss - 0.0, iou_score - 0.7917]
#
# Epoch: 125
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1332, RNLoss - 0.0, iou_score - 0.7741]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.96it/s, dice_loss - 0.1216, RNLoss - 0.0, iou_score - 0.7919]
#
# Epoch: 126
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1323, RNLoss - 0.0, iou_score - 0.7755]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.88it/s, dice_loss - 0.1216, RNLoss - 0.0, iou_score - 0.7919]
#
# Epoch: 127
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1328, RNLoss - 0.0, iou_score - 0.7746]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.39it/s, dice_loss - 0.1214, RNLoss - 0.0, iou_score - 0.7919]
#
# Epoch: 128
# train: 100%|██████████| 37/37 [00:18<00:00,  2.05it/s, dice_loss - 0.1318, RNLoss - 0.0, iou_score - 0.7757]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.06it/s, dice_loss - 0.1209, RNLoss - 0.0, iou_score - 0.7927]
#
# Epoch: 129
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1323, RNLoss - 0.05617, iou_score - 0.7752]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.70it/s, dice_loss - 0.121, RNLoss - 0.0, iou_score - 0.7926]
#
# Epoch: 130
# train: 100%|██████████| 37/37 [00:18<00:00,  2.00it/s, dice_loss - 0.129, RNLoss - 0.0, iou_score - 0.7802]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.93it/s, dice_loss - 0.1214, RNLoss - 0.0, iou_score - 0.7922]
#
# Epoch: 131
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1304, RNLoss - 0.0, iou_score - 0.7776]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.12it/s, dice_loss - 0.121, RNLoss - 0.0, iou_score - 0.7928]
#
# Epoch: 132
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1319, RNLoss - 0.0, iou_score - 0.7758]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.71it/s, dice_loss - 0.1205, RNLoss - 0.0, iou_score - 0.7936]
#
# Epoch: 133
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1327, RNLoss - 0.0, iou_score - 0.7751]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.67it/s, dice_loss - 0.1202, RNLoss - 0.0, iou_score - 0.7937]
#
# Epoch: 134
# train: 100%|██████████| 37/37 [00:17<00:00,  2.13it/s, dice_loss - 0.1272, RNLoss - 0.0, iou_score - 0.7825]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.91it/s, dice_loss - 0.1202, RNLoss - 0.0, iou_score - 0.7941]
#
# Epoch: 135
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1292, RNLoss - 0.0, iou_score - 0.7803]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.46it/s, dice_loss - 0.1198, RNLoss - 0.0, iou_score - 0.7941]
#
# Epoch: 136
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1284, RNLoss - 0.0, iou_score - 0.7807]
# valid: 100%|██████████| 98/98 [00:04<00:00, 23.72it/s, dice_loss - 0.1198, RNLoss - 0.0, iou_score - 0.7943]
#
# Epoch: 137
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1313, RNLoss - 0.0, iou_score - 0.7764]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.49it/s, dice_loss - 0.1191, RNLoss - 0.0, iou_score - 0.7953]
#
# Epoch: 138
# train: 100%|██████████| 37/37 [00:18<00:00,  2.02it/s, dice_loss - 0.1254, RNLoss - 0.0, iou_score - 0.7855]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.86it/s, dice_loss - 0.1192, RNLoss - 0.0, iou_score - 0.7951]
#
# Epoch: 139
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1284, RNLoss - 0.04583, iou_score - 0.7809]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.35it/s, dice_loss - 0.1191, RNLoss - 0.0, iou_score - 0.7951]
#
# Epoch: 140
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1317, RNLoss - 0.0, iou_score - 0.7751]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.45it/s, dice_loss - 0.1218, RNLoss - 0.0, iou_score - 0.7909]
#
# Epoch: 141
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1303, RNLoss - 0.0, iou_score - 0.7777]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.50it/s, dice_loss - 0.1212, RNLoss - 0.0, iou_score - 0.7918]
#
# Epoch: 142
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.1323, RNLoss - 0.0, iou_score - 0.775]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.79it/s, dice_loss - 0.1208, RNLoss - 0.0, iou_score - 0.7922]
#
# Epoch: 143
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1299, RNLoss - 0.0, iou_score - 0.7781]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.97it/s, dice_loss - 0.1212, RNLoss - 0.0, iou_score - 0.7919]
#
# Epoch: 144
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.128, RNLoss - 0.0, iou_score - 0.7811]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.06it/s, dice_loss - 0.1205, RNLoss - 0.0, iou_score - 0.7927]
#
# Epoch: 145
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1298, RNLoss - 0.0, iou_score - 0.7789]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.61it/s, dice_loss - 0.12, RNLoss - 0.0, iou_score - 0.7935]
#
# Epoch: 146
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1274, RNLoss - 0.0, iou_score - 0.7831]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.48it/s, dice_loss - 0.12, RNLoss - 0.0, iou_score - 0.7936]
#
# Epoch: 147
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.129, RNLoss - 0.0, iou_score - 0.7794]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.54it/s, dice_loss - 0.1204, RNLoss - 0.0, iou_score - 0.7929]
#
# Epoch: 148
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1287, RNLoss - 0.0, iou_score - 0.7806]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.71it/s, dice_loss - 0.1199, RNLoss - 0.0, iou_score - 0.7938]
#
# Epoch: 149
# train: 100%|██████████| 37/37 [00:18<00:00,  2.03it/s, dice_loss - 0.129, RNLoss - 0.0, iou_score - 0.7788]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.86it/s, dice_loss - 0.1195, RNLoss - 0.0, iou_score - 0.7943]
#
# Epoch: 150
# train: 100%|██████████| 37/37 [00:17<00:00,  2.14it/s, dice_loss - 0.1285, RNLoss - 0.0, iou_score - 0.7804]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.36it/s, dice_loss - 0.1196, RNLoss - 0.0, iou_score - 0.794]
#
# Epoch: 151
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1271, RNLoss - 0.0, iou_score - 0.7825]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.86it/s, dice_loss - 0.1192, RNLoss - 0.0, iou_score - 0.7945]
#
# Epoch: 152
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1288, RNLoss - 0.0, iou_score - 0.7796]
# valid: 100%|██████████| 98/98 [00:04<00:00, 24.31it/s, dice_loss - 0.1193, RNLoss - 0.0, iou_score - 0.7946]
#
# Epoch: 153
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1271, RNLoss - 0.003072, iou_score - 0.7831]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.88it/s, dice_loss - 0.1195, RNLoss - 0.0, iou_score - 0.7943]
#
# Epoch: 154
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1273, RNLoss - 0.0, iou_score - 0.7824]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.23it/s, dice_loss - 0.1193, RNLoss - 0.0, iou_score - 0.795]
#
# Epoch: 155
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.126, RNLoss - 0.0, iou_score - 0.7845]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.97it/s, dice_loss - 0.1188, RNLoss - 0.0, iou_score - 0.7957]
#
# Epoch: 156
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.1254, RNLoss - 0.0, iou_score - 0.7857]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.68it/s, dice_loss - 0.1186, RNLoss - 0.0, iou_score - 0.7961]
#
# Epoch: 157
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1267, RNLoss - 0.004704, iou_score - 0.7836]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.75it/s, dice_loss - 0.1186, RNLoss - 0.0, iou_score - 0.7962]
#
# Epoch: 158
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1297, RNLoss - 0.0, iou_score - 0.7786]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.30it/s, dice_loss - 0.1184, RNLoss - 0.0, iou_score - 0.7964]
#
# Epoch: 159
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1267, RNLoss - 0.0, iou_score - 0.783]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.90it/s, dice_loss - 0.1179, RNLoss - 0.0, iou_score - 0.7972]
#
# Epoch: 160
# train: 100%|██████████| 37/37 [00:17<00:00,  2.11it/s, dice_loss - 0.1273, RNLoss - 0.0, iou_score - 0.7826]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.73it/s, dice_loss - 0.1178, RNLoss - 0.0, iou_score - 0.7971]
#
# Epoch: 161
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1254, RNLoss - 0.0, iou_score - 0.7851]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.82it/s, dice_loss - 0.1176, RNLoss - 0.0, iou_score - 0.7975]
#
# Epoch: 162
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.127, RNLoss - 0.0, iou_score - 0.7827]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.44it/s, dice_loss - 0.1178, RNLoss - 0.0, iou_score - 0.7971]
#
# Epoch: 163
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.127, RNLoss - 0.0, iou_score - 0.7827]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.94it/s, dice_loss - 0.1174, RNLoss - 0.0, iou_score - 0.7976]
#
# Epoch: 164
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1253, RNLoss - 0.0, iou_score - 0.7853]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.24it/s, dice_loss - 0.117, RNLoss - 0.0, iou_score - 0.7983]
#
# Epoch: 165
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1247, RNLoss - 0.0, iou_score - 0.786]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.53it/s, dice_loss - 0.117, RNLoss - 0.0, iou_score - 0.7981]
#
# Epoch: 166
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.1269, RNLoss - 0.0005063, iou_score - 0.7824]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.08it/s, dice_loss - 0.1166, RNLoss - 0.0, iou_score - 0.7986]
#
# Epoch: 167
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.124, RNLoss - 0.0, iou_score - 0.7867]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.17it/s, dice_loss - 0.1166, RNLoss - 0.0, iou_score - 0.7985]
#
# Epoch: 168
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1254, RNLoss - 0.0, iou_score - 0.7847]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.13it/s, dice_loss - 0.1167, RNLoss - 0.0, iou_score - 0.7986]
#
# Epoch: 169
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1238, RNLoss - 0.0, iou_score - 0.7874]
# valid: 100%|██████████| 98/98 [00:03<00:00, 27.69it/s, dice_loss - 0.1166, RNLoss - 0.0, iou_score - 0.7985]
#
# Epoch: 170
# train: 100%|██████████| 37/37 [00:17<00:00,  2.06it/s, dice_loss - 0.1226, RNLoss - 0.0, iou_score - 0.7892]
# valid: 100%|██████████| 98/98 [00:03<00:00, 24.96it/s, dice_loss - 0.1162, RNLoss - 0.0, iou_score - 0.7991]
#
# Epoch: 171
# train: 100%|██████████| 37/37 [00:17<00:00,  2.10it/s, dice_loss - 0.1219, RNLoss - 0.0, iou_score - 0.79]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.84it/s, dice_loss - 0.1158, RNLoss - 0.0, iou_score - 0.7997]
#
# Epoch: 172
# train: 100%|██████████| 37/37 [00:17<00:00,  2.12it/s, dice_loss - 0.1231, RNLoss - 0.0, iou_score - 0.7883]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.05it/s, dice_loss - 0.1158, RNLoss - 0.0, iou_score - 0.7996]
#
# Epoch: 173
# train: 100%|██████████| 37/37 [00:17<00:00,  2.07it/s, dice_loss - 0.122, RNLoss - 0.0, iou_score - 0.7896]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.22it/s, dice_loss - 0.1157, RNLoss - 0.0, iou_score - 0.7999]
#
# Epoch: 174
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1239, RNLoss - 0.0, iou_score - 0.7868]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.45it/s, dice_loss - 0.1157, RNLoss - 0.0, iou_score - 0.7998]
#
# Epoch: 175
# train: 100%|██████████| 37/37 [00:18<00:00,  2.04it/s, dice_loss - 0.1218, RNLoss - 0.0, iou_score - 0.79]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.53it/s, dice_loss - 0.1155, RNLoss - 0.0, iou_score - 0.8]
#
# Epoch: 176
# train: 100%|██████████| 37/37 [00:17<00:00,  2.15it/s, dice_loss - 0.1216, RNLoss - 0.0, iou_score - 0.79]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.60it/s, dice_loss - 0.1155, RNLoss - 0.0, iou_score - 0.8002]
#
# Epoch: 177
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.122, RNLoss - 0.0, iou_score - 0.7899]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.56it/s, dice_loss - 0.1156, RNLoss - 0.0, iou_score - 0.8]
#
# Epoch: 178
# train: 100%|██████████| 37/37 [00:17<00:00,  2.08it/s, dice_loss - 0.1237, RNLoss - 0.0, iou_score - 0.7868]
# valid: 100%|██████████| 98/98 [00:03<00:00, 26.62it/s, dice_loss - 0.115, RNLoss - 0.0, iou_score - 0.801]
#
# Epoch: 179
# train: 100%|██████████| 37/37 [00:17<00:00,  2.09it/s, dice_loss - 0.1225, RNLoss - 0.06844, iou_score - 0.7893]
# valid: 100%|██████████| 98/98 [00:03<00:00, 25.78it/s, dice_loss - 0.1148, RNLoss - 0.0, iou_score - 0.801]

# %%
import matplotlib.pyplot as plt
import matplotlib
import pylab as py
matplotlib.rcParams.update({                      # setup matplotlib to use latex for output
        "pgf.texsystem": "pdflatex",              # change this if using xetex or lautex
        "text.usetex": True,                      # use LaTeX to write all text
        "figure.figsize": (9, 5),                 # default fig size of 0.9 textwidth
        "figure.dpi": 300,
        "font.family": "serif",
        "font.serif": [],                         # blank entries should cause plots to inherit fonts from the document
        "font.sans-serif": [],
        "font.monospace": [],
        "axes.labelsize": 20,                     # LaTeX default is 10pt font.
        'axes.titlesize': 15,
        "font.size": 15,
        "legend.fontsize": 20,                    # Make the legend/label fonts a little smaller
        "xtick.labelsize": 16,
        "ytick.labelsize": 16,
        })

# %%
# # Train

# fig, ax = plt.subplots(figsize=(8, 6))
# plt.plot(conv_train['iou'], label='IoU Score')
# plt.plot(conv_train['dice'], label='Dice Loss')
# plt.plot(conv_train['RN'], label='RN Loss')
# plt.plot(np.arange(200), np.ones(200), 'k--')
# plt.xlabel('Epoch')
# plt.ylabel('Percent')
# py.legend(loc='lower right')
# plt.show()

# %% [markdown]
# #### Iterator for Test Data

# %%
best_model = model#torch.load('saved_models/best_model_random_lambda_01.pth')

test_epoch = ValidEpoch(
    model=best_model,
    loss = loss,
    metrics = metrics,
    device = DEVICE,
    verbose = True,
    rn_model = rn_model,
    rn_loss = rn_loss,
    lambda_r = 0.001,
)

# %%
test_log = test_epoch.run(test_loader)
print('IOU Score: {}'.format(test_log['iou_score']))
# Out:
# valid: 100%|██████████| 99/99 [00:08<00:00, 12.06it/s, dice_loss - 0.115, RNLoss - 0.0, iou_score - 0.8005]
# IOU Score: 0.8004799587558014

# %%
test_dataset_viz = Dataset(
    x_test_dir,
    masks_dir=None,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing_unlabeled(preprocessing_fn),
    classes = CLASSES,
)

# %%
num_test_img = len(test_dataset)

# %%
image_viz, mask_viz = test_dataset_viz[0]
image, mask = test_dataset[0]
img_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
pred_mask = best_model.predict(img_tensor)
pred_mask = pred_mask.squeeze().cpu().numpy().round()
plt.imshow(get_color_img(pred_mask, normal=False))
plt.title('Prediction')
plt.show()
plt.imshow(get_color_img(mask, normal=False))
plt.title('Ground-Truth')
plt.show()

# %%
from scripts.dorsal_to import explicit_dorsal_to_nobatch, rn_dorsal_to_nobatch

x_unlabeled_test_dir = '/raid/maruf/inhs-800/img_crp/'
test_dataset_unlabeled = Dataset(
    x_unlabeled_test_dir,
    masks_dir=None,
    augmentation = get_validation_augmentation(),
    preprocessing = get_preprocessing_unlabeled(preprocessing_fn),
    classes = CLASSES,
)
test_loader_unlabeled = DataLoader(test_dataset_unlabeled, batch_size=1)
num_test_img = len(test_dataset_unlabeled)
unlabeled_inconsistency = 0
for test_no in range(num_test_img):
    image, mask = test_dataset_unlabeled[test_no]
    img_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
    pred_mask = best_model.predict(img_tensor)
    pred_mask = pred_mask.squeeze().cpu().numpy().round()
    unlabeled_inconsistency += explicit_dorsal_to_nobatch(labelmap=pred_mask, tensor=False)
    
    if test_no == 1000:
        break
    if test_no % 100 == 0:
        print('\n',test_no, 'done!\n')
    else:
        print('.', end='')
print('Unlabeled Inconsistency for {} model: {}'.format('SM_RN_2S', unlabeled_inconsistency))
# Out:
#  0 done!
#
# ...................................................................................................
#  100 done!
#
# ...................................................................................................
#  200 done!
#
# ...................................................................................................
#  300 done!
#
# ...................................................................................................
#  400 done!
#
# ...................................................................................................
#  500 done!
#
# ...................................................................................................
#  600 done!
#
# ...................................................................................................
#  700 done!
#
# ...................................................................................................
#  800 done!
#
# ...................................................................................................
#  900 done!
#
# ...................................................................................................Unlabeled Inconsistency for SM_RN_2S model: 0
